# %%
import pandas as pd
import numpy as np
import matplotlib as plt

#/usr/local/opt/python@3.10/bin/python3.10 -m pip install matplotlib

df = pd.read_csv('/Users/matthewherzog/Desktop/Folders/Code/Projects/jupiternotebook-ncaamb/US_BASKETBALL_COLLAGE.csv')

df.head()
# Out:
#                          school           city       state       region  \
# 0  Abilene Christian University        Abilene       Texas    Mid South
# 1     Academy of Art University  San Francisco  California   West Coast
# 2        Adams State University        Alamosa    Colorado   South West
# 3            Adelphi University    Garden City    New York   North East
# 4                Adrian College         Adrian    Michigan  Great Lakes
#
#                                       conference division
# 0                    Western Athletic Conference  NCAA D1
# 1                        Pacific West Conference  NCAA D2
# 2             Rocky Mountain Athletic Conference  NCAA D2
# 3                        Northeast-10 Conference  NCAA D2
# 4  Michigan Intercollegiate Athletic Association  NCAA D3

# %%
df.head(10)
# Out:
#                          school           city        state       region  \
# 0  Abilene Christian University        Abilene        Texas    Mid South
# 1     Academy of Art University  San Francisco   California   West Coast
# 2        Adams State University        Alamosa     Colorado   South West
# 3            Adelphi University    Garden City     New York   North East
# 4                Adrian College         Adrian     Michigan  Great Lakes
# 5        Alabama A&M University         Normal      Alabama   South East
# 6      Alabama State University     Montgomery      Alabama   South East
# 7       Albany State University         Albany      Georgia   South East
# 8       Albertus Magnus College      New Haven  Connecticut  New England
# 9                Albion College         Albion     Michigan  Great Lakes
#
#                                       conference division
# 0                    Western Athletic Conference  NCAA D1
# ...

# %%
df.tail(10)
# Out:
#                               school          city         state       region  \
# 1701         Wright State University        Dayton          Ohio  Great Lakes
# 1702               Xavier University    Cincinnati          Ohio  Great Lakes
# 1703  Xavier University of Louisiana   New Orleans     Louisiana    Mid South
# 1704           Yakima Valley College        Yakima    Washington   West Coast
# 1705                 Yale University     New Haven   Connecticut  New England
# 1706              Yeshiva University      New York      New York   North East
# 1707                    York College          York      Nebraska     Mid West
# 1708    York College of Pennsylvania          York  Pennsylvania   North East
# 1709            Young Harris College  Young Harris       Georgia   South East
# 1710     Youngstown State University    Youngstown          Ohio  Great Lakes
#
#                                  conference division
# 1701                         Horizon League  NCAA D1
# ...

# %%
df[df['division'] == 'NCAA D1']['division'].count()
# Out:
# 358

# %%
df['division'].value_counts()
# Out:
# division
# JC         439
# NCAA D3    393
# NCAA D1    358
# NCAA D2    301
# NAIA       219
# NCCAA        1
# Name: count, dtype: int64

# %%
df['conference'].value_counts()
# Out:
# conference
# Northwest Athletic Conference                     28
# Pennsylvania State Athletic Conference            18
# Great Lakes Valley Conference                     17
# Southern Intercollegiate Athletic Conference      16
# Kansas Jayhawk Community College Conference       16
#                                                   ..
# Nebraska Community College Athletic Conference     1
# The Great Rivers Athletic Conference               1
# Ohio Collegiate Athletic Conference (USCAA)        1
# Western Junior College Athletic Conference         1
# MCCAA                                              1
# Name: count, Length: 290, dtype: int64

# %%
division = df['division'].value_counts()
conference_counts = df['conference'].value_counts()

division.plot(kind='bar')
# Out:
# <Axes: xlabel='division'>
